# %%
import os
import json

def gen(folderPathMonster,foldetPathSaveDict):
    nbFile =len(os.listdir(folderPathMonster)) 
    d={}
    d2={}
    for i in range(0,nbFile):
        f=json.load(open(folderPathMonster+'/'+str(i)+'.json'))
        name=f['name']
        powers=[]
        
        for j in range(0,len(f['mechanics'])) :
            powers.append(f['mechanics'][j])
        monster={}
        monster['powers']=powers
        monster['number']=i
        d[name]=monster
        d2[str(i)]=name
    with open(foldetPathSaveDict+'/monsters.json', 'w', encoding='utf-8') as f:
        json.dump(d, f)
    with open(foldetPathSaveDict+'/num_monsters.json', 'w', encoding='utf-8') as f:
        json.dump(d2, f)

# %%
gen('partiesHS/cards_extract','partiesHS/cards_extract')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e8d4674cfcd0> in <module>
# ----> 1 gen('partiesHS/cards_extract','partiesHS/cards_extract')
#
# <ipython-input-1-49e505f44754> in gen(folderPathMonster, foldetPathSaveDict)
#       3
#       4 def gen(folderPathMonster,foldetPathSaveDict):
# ----> 5     nbFile =len(os.listdir(folderPathMonster))
#       6     d={}
#       7     d2={}
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'partiesHS/cards_extract'
